# %% [markdown]
# # Exercise 2.C
# ## Lab 1 Working with defining custom functions

# %%
def favorite_things(name, movie, music):
    return f"Name: {name}\nFavorite Movie: {movie}\nFavorite Musician/Band: {music}"

print(favorite_things("Sha'Rya Weaver", "Black Panther", "Michael Jackson"))
# Out:
# Name: Sha'Rya Weaver
# Favorite Movie: Black Panther
# Favorite Musician/Band: Michael Jackson

# %%
def why_im_here(purpose):
    return purpose
print(why_im_here("I joined thenYear Up United Data Analyst program to expand my knowledge of being a data analyst and because it aligns with what I enjoy.")
